# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
from statsmodels.stats.diagnostic import het_white

import scipy
from scipy import stats
from itertools import combinations
from scipy import signal
import math

# %%
# base code
import numpy as np
import seaborn as sns
import statsmodels
from statsmodels.tools.tools import maybe_unwrap_results
from statsmodels.graphics.gofplots import ProbPlot
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
from typing import Type

style_talk = 'seaborn-talk'    #refer to plt.style.available

class Linear_Reg_Diagnostic():
    """
    Diagnostic plots to identify potential problems in a linear regression fit.
    Mainly,
        a. non-linearity of data
        b. Correlation of error terms
        c. non-constant variance
        d. outliers
        e. high-leverage points
        f. collinearity

    Author:
        Prajwal Kafle (p33ajkafle@gmail.com, where 3 = r)
        Does not come with any sort of warranty.
        Please test the code one your end before using.
    """

    def __init__(self,
                 results: Type[statsmodels.regression.linear_model.RegressionResultsWrapper]) -> None:
        """
        For a linear regression model, generates following diagnostic plots:

        a. residual
        b. qq
        c. scale location and
        d. leverage

        and a table

        e. vif

        Args:
            results (Type[statsmodels.regression.linear_model.RegressionResultsWrapper]):
                must be instance of statsmodels.regression.linear_model object

        Raises:
            TypeError: if instance does not belong to above object

        Example:
        >>> import numpy as np
        >>> import pandas as pd
        >>> import statsmodels.formula.api as smf
        >>> x = np.linspace(-np.pi, np.pi, 100)
        >>> y = 3*x + 8 + np.random.normal(0,1, 100)
        >>> df = pd.DataFrame({'x':x, 'y':y})
        >>> res = smf.ols(formula= "y ~ x", data=df).fit()
        >>> cls = Linear_Reg_Diagnostic(res)
        >>> cls(plot_context="seaborn-paper")

        In case you do not need all plots you can also independently make an individual plot/table
        in following ways

        >>> cls = Linear_Reg_Diagnostic(res)
        >>> cls.residual_plot()
        >>> cls.qq_plot()
        >>> cls.scale_location_plot()
        >>> cls.leverage_plot()
        >>> cls.vif_table()
        """

        if isinstance(results, statsmodels.regression.linear_model.RegressionResultsWrapper) is False:
            raise TypeError("result must be instance of statsmodels.regression.linear_model.RegressionResultsWrapper object")

        self.results = maybe_unwrap_results(results)

        self.y_true = self.results.model.endog
        self.y_predict = self.results.fittedvalues
        self.xvar = self.results.model.exog
        self.xvar_names = self.results.model.exog_names

        self.residual = np.array(self.results.resid)
        influence = self.results.get_influence()
        self.residual_norm = influence.resid_studentized_internal
        self.leverage = influence.hat_matrix_diag
        self.cooks_distance = influence.cooks_distance[0]
        self.nparams = len(self.results.params)

    def __call__(self, plot_context='seaborn-paper'):
        # print(plt.style.available)
        with plt.style.context(plot_context):
            fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))
            self.residual_plot(ax=ax[0,0])
            self.qq_plot(ax=ax[0,1])
            self.scale_location_plot(ax=ax[1,0])
            self.leverage_plot(ax=ax[1,1])
            plt.show()

        self.vif_table()
        return fig, ax


    def residual_plot(self, ax=None):
        """
        Residual vs Fitted Plot

        Graphical tool to identify non-linearity.
        (Roughly) Horizontal red line is an indicator that the residual has a linear pattern
        """
        if ax is None:
            fig, ax = plt.subplots()

        sns.residplot(
            x=self.y_predict,
            y=self.residual,
            lowess=True,
            scatter_kws={'alpha': 0.5},
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        residual_abs = np.abs(self.residual)
        abs_resid = np.flip(np.sort(residual_abs))
        abs_resid_top_3 = abs_resid[:3]
        for i, _ in enumerate(abs_resid_top_3):
            ax.annotate(
                i,
                xy=(self.y_predict[i], self.residual[i]),
                color='C3')

        ax.set_title('Residuals vs Fitted', fontweight="bold")
        ax.set_xlabel('Fitted values')
        ax.set_ylabel('Residuals')
        return ax

    def qq_plot(self, ax=None):
        """
        Standarized Residual vs Theoretical Quantile plot

        Used to visually check if residuals are normally distributed.
        Points spread along the diagonal line will suggest so.
        """
        if ax is None:
            fig, ax = plt.subplots()

        QQ = ProbPlot(self.residual_norm)
        QQ.qqplot(line='45', alpha=0.5, lw=1, ax=ax)

        # annotations
        abs_norm_resid = np.flip(np.argsort(np.abs(self.residual_norm)), 0)
        abs_norm_resid_top_3 = abs_norm_resid[:3]
        for r, i in enumerate(abs_norm_resid_top_3):
            ax.annotate(
                i,
                xy=(np.flip(QQ.theoretical_quantiles, 0)[r], self.residual_norm[i]),
                ha='right', color='C3')

        ax.set_title('Normal Q-Q', fontweight="bold")
        ax.set_xlabel('Theoretical Quantiles')
        ax.set_ylabel('Standardized Residuals')
        return ax

    def scale_location_plot(self, ax=None):
        """
        Sqrt(Standarized Residual) vs Fitted values plot

        Used to check homoscedasticity of the residuals.
        Horizontal line will suggest so.
        """
        if ax is None:
            fig, ax = plt.subplots()

        residual_norm_abs_sqrt = np.sqrt(np.abs(self.residual_norm))

        ax.scatter(self.y_predict, residual_norm_abs_sqrt, alpha=0.5);
        sns.regplot(
            x=self.y_predict,
            y=residual_norm_abs_sqrt,
            scatter=False, ci=False,
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        abs_sq_norm_resid = np.flip(np.argsort(residual_norm_abs_sqrt), 0)
        abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]
        for i in abs_sq_norm_resid_top_3:
            ax.annotate(
                i,
                xy=(self.y_predict[i], residual_norm_abs_sqrt[i]),
                color='C3')
        ax.set_title('Scale-Location', fontweight="bold")
        ax.set_xlabel('Fitted values')
        ax.set_ylabel(r'$\sqrt{|\mathrm{Standardized\ Residuals}|}$');
        return ax

    def leverage_plot(self, ax=None):
        """
        Residual vs Leverage plot

        Points falling outside Cook's distance curves are considered observation that can sway the fit
        aka are influential.
        Good to have none outside the curves.
        """
        if ax is None:
            fig, ax = plt.subplots()

        ax.scatter(
            self.leverage,
            self.residual_norm,
            alpha=0.5);

        sns.regplot(
            x=self.leverage,
            y=self.residual_norm,
            scatter=False,
            ci=False,
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        leverage_top_3 = np.flip(np.argsort(self.cooks_distance), 0)[:3]
        for i in leverage_top_3:
            ax.annotate(
                i,
                xy=(self.leverage[i], self.residual_norm[i]),
                color = 'C3')

        xtemp, ytemp = self.__cooks_dist_line(0.5) # 0.5 line
        ax.plot(xtemp, ytemp, label="Cook's distance", lw=1, ls='--', color='red')
        xtemp, ytemp = self.__cooks_dist_line(1) # 1 line
        ax.plot(xtemp, ytemp, lw=1, ls='--', color='red')

        ax.set_xlim(0, max(self.leverage)+0.01)
        ax.set_title('Residuals vs Leverage', fontweight="bold")
        ax.set_xlabel('Leverage')
        ax.set_ylabel('Standardized Residuals')
        ax.legend(loc='upper right')
        return ax

    def vif_table(self):
        """
        VIF table

        VIF, the variance inflation factor, is a measure of multicollinearity.
        VIF > 5 for a variable indicates that it is highly collinear with the
        other input variables.
        """
        vif_df = pd.DataFrame()
        vif_df["Features"] = self.xvar_names
        vif_df["VIF Factor"] = [variance_inflation_factor(self.xvar, i) for i in range(self.xvar.shape[1])]

        print(vif_df
                .sort_values("VIF Factor")
                .round(2))


    def __cooks_dist_line(self, factor):
        """
        Helper function for plotting Cook's distance curves
        """
        p = self.nparams
        formula = lambda x: np.sqrt((factor * p * (1 - x)) / x)
        x = np.linspace(0.001, max(self.leverage), 50)
        y = formula(x)
        return x, y

# %% [markdown]
# # Read in the data

# %%
#Lemmon Valley
df1=pd.read_hdf('dfs_for_spatialregression/1.11.22_spatial.hdf')
df2=pd.read_hdf('dfs_for_spatialregression/1.15.22_spatial.hdf')
df3=pd.read_hdf('dfs_for_spatialregression/6.1.22_spatial.hdf')
df4=pd.read_hdf('dfs_for_spatialregression/6.3.22_spatial.hdf')
df5=pd.read_hdf('dfs_for_spatialregression/10.20.20_spatial.hdf')
all_desert=pd.concat([df1,df2,df3,df4,df5])

#Urban
df5=pd.read_hdf('dfs_for_spatialregression/9.26.21_spatial.hdf')
df6=pd.read_hdf('dfs_for_spatialregression/10.30.21_spatial.hdf')
df7=pd.read_hdf('dfs_for_spatialregression/1.8.22_spatial.hdf')
df8=pd.read_hdf('dfs_for_spatialregression/4.30.22_spatial.hdf')
df9=pd.read_hdf('dfs_for_spatialregression/5.1.22_spatial.hdf')

all_urban=pd.concat([df5,df6,df7,df8,df9])

# %% [markdown]
# # Plot the relationship between variables

# %%
fig, ax = plt.subplots(figsize=(18,4), ncols=3)
ax[0].scatter(all_desert.speed_avg, all_desert.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[0].scatter(all_urban.speed_avg, all_urban.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[0].set_ylim(0,120)
ax[0].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[0].set_xlabel('10-minute average wind speed (m/s)')
#ax[0].legend(bbox_to_anchor=(1,1))


ax[1].scatter(all_desert.distance, all_desert.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[1].scatter(all_urban.distance, all_urban.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[1].set_ylim(0,120)
#ax[1].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[1].set_xlabel('Distance between sensors (m)')
#ax[1].legend(bbox_to_anchor=(1,1))

ax[2].scatter(all_desert.control_D_100, all_desert.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[2].scatter(all_urban.control_D_100, all_urban.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[2].set_ylim(0,120)
#ax[2].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[2].set_xlabel('10-minute standard deviation in direction (control tower data)')
ax[2].legend(bbox_to_anchor=(1,1))

# %%
'''
We can see from the plot above that there are some clear differences in the rane of data collected:

- It looks like there may be a similar relationship between wind speed and difference in direction, 
but the wind speed measurements in our urban data only span from 0-2.5 m/s, whereas the desert data
spans from 0-6 m/s. Also, there is a clear non-linear trend in the desert data, which is most noticable
around the 3 m/s threshold. 

- The distances measured between sensors range from 0-40 meters in the urban data, but span 0-175 meters
in the desert. 

- The measured differences in direction are quite variable in comparision to our control tower data.
This is to be expected since data was collected on different days, however, it is difficult to see 
if there is any discernable relationship. 
'''

# %% [markdown]
# # Segment the data to account for differences in distance and speed measurements

# %%
all_desert_40 = all_desert[all_desert.distance <=40]
all_urban_40 = all_urban[all_urban.distance <=40]
all_desert_40 = all_desert_40[all_desert_40.speed_avg <=2]
all_urban_40 = all_urban_40[all_urban_40.speed_avg <=2]

# %%
fig, ax = plt.subplots(figsize=(18,4), ncols=3)
ax[0].scatter(all_desert_40.speed_avg, all_desert_40.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[0].scatter(all_urban_40.speed_avg, all_urban_40.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[0].set_ylim(0,120)
ax[0].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[0].set_xlabel('10-minute average wind speed (m/s)')
#ax[0].legend(bbox_to_anchor=(1,1))


ax[1].scatter(all_desert_40.distance, all_desert_40.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[1].scatter(all_urban_40.distance, all_urban_40.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[1].set_ylim(0,120)
#ax[1].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[1].set_xlabel('Distance between sensors (m)')
#ax[1].legend(bbox_to_anchor=(1,1))

ax[2].scatter(all_desert_40.control_D_100, all_desert_40.direction_diff, alpha=.4, color='blue', label='Desert data')
ax[2].scatter(all_urban_40.control_D_100, all_urban_40.direction_diff, alpha=.15, color='purple', label='Urban data')
ax[2].set_ylim(0,120)
#ax[2].set_ylabel('10-minute average difference in \n wind direction between sensors (degrees)')
ax[2].set_xlabel('10-minute standard deviation in direction (control tower data)')
ax[2].legend(bbox_to_anchor=(1,1))

# %%
'''
Things still don't look perfect, but the relationship between difference in direction and wind speed
looks promising... still not sure about the control data

'''

# %%
mod = smf.ols(formula='direction_diff ~ speed_avg + control_D_100', data=all_desert_40)
res = mod.fit(cov_type='cluster', cov_kwds={'groups': all_desert_40.group})
#implementing robust cluster correlation based on day of data collection 
print(res.summary())

cls = Linear_Reg_Diagnostic(res)
fig, ax = cls()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         direction_diff   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     8.070
# Date:                Mon, 28 Nov 2022   Prob (F-statistic):             0.0621
# Time:                        22:19:55   Log-Likelihood:                -1674.4
# No. Observations:                 431   AIC:                             3355.
# Df Residuals:                     428   BIC:                             3367.
# Df Model:                           2
# Covariance Type:              cluster
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        79.3390      9.073      8.745      0.000      61.556      97.122
# ...

# %%
# Conduct the Breusch-Pagan test
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
 
# Get the test result
test_result = sms.het_breuschpagan(res.resid, res.model.exog)
 
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', 10.914611640106482),
#  ('p-value', 0.004265031040720063),
#  ('f-value', 5.560124097869668),
#  ('f p-value', 0.004131477910412485)]

# %%
#perform White's test
white_test = het_white(res.resid,  res.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
lzip(labels, white_test)
# Out:
# [('Test Statistic', 11.62373270016806),
#  ('Test Statistic p-value', 0.04032354629299435),
#  ('F-Statistic', 2.3559208199254305),
#  ('F-Test p-value', 0.039752863167585556)]

# %%
mod = smf.ols(formula='direction_diff ~ speed_avg + control_D_100', data=all_urban_40)
res = mod.fit(cov_type='cluster', cov_kwds={'groups': all_urban_40.group})
#implementing robust cluster correlation based on day of data collection 
print(res.summary())


cls = Linear_Reg_Diagnostic(res)
fig, ax = cls()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         direction_diff   R-squared:                       0.314
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     17.02
# Date:                Mon, 28 Nov 2022   Prob (F-statistic):             0.0111
# Time:                        22:20:19   Log-Likelihood:                -10550.
# No. Observations:                2722   AIC:                         2.111e+04
# Df Residuals:                    2719   BIC:                         2.112e+04
# Df Model:                           2
# Covariance Type:              cluster
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        84.6949      6.463     13.104      0.000      72.027      97.363
# ...

# %%
# Conduct the Breusch-Pagan test
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
 
# Get the test result
test_result = sms.het_breuschpagan(res.resid, res.model.exog)
 
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', 2.2398534126448895),
#  ('p-value', 0.3263037097455023),
#  ('f-value', 1.1196136976679472),
#  ('f p-value', 0.32655629590890095)]

# %%
#perform White's test
white_test = het_white(res.resid,  res.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
lzip(labels, white_test)
# Out:
# [('Test Statistic', 31.63035929467056),
#  ('Test Statistic p-value', 7.031306414393039e-06),
#  ('F-Statistic', 6.386338482603693),
#  ('F-Test p-value', 6.619153969037892e-06)]

# %% [markdown]
# # using catagorical regression

# %%
all_desert_40['env']=0 # category: zero for desert
all_urban_40['env']=1 # category: one for urban

both_dfs = pd.concat([all_desert_40, all_urban_40])

# %%
mod = smf.ols(formula='direction_diff ~ speed_avg + control_D_100', data=both_dfs)
res = mod.fit(cov_type='cluster', cov_kwds={'groups': both_dfs.group})
#res = mod.fit()
#implementing robust cluster correlation based on day of data collection 
print(res.summary())

cls = Linear_Reg_Diagnostic(res)
fig, ax = cls()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         direction_diff   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     23.45
# Date:                Mon, 28 Nov 2022   Prob (F-statistic):           0.000451
# Time:                        23:39:50   Log-Likelihood:                -12569.
# No. Observations:                3153   AIC:                         2.514e+04
# Df Residuals:                    3150   BIC:                         2.516e+04
# Df Model:                           2
# Covariance Type:              cluster
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        79.2723      6.284     12.615      0.000      66.956      91.589
# ...

# %%
plt.hist(res.resid, bins=20)
# Out:
# (array([  3.,   9.,  13.,  28.,  54.,  92., 172., 251., 359., 403., 404.,
#         405., 363., 253., 166.,  91.,  50.,  29.,   5.,   3.]),
#  array([-46.51393224, -42.05708533, -37.60023841, -33.1433915 ,
#         -28.68654458, -24.22969767, -19.77285075, -15.31600384,
#         -10.85915693,  -6.40231001,  -1.9454631 ,   2.51138382,
#           6.96823073,  11.42507765,  15.88192456,  20.33877148,
#          24.79561839,  29.2524653 ,  33.70931222,  38.16615913,
#          42.62300605]),
#  <BarContainer object of 20 artists>)

# %%
# Conduct the Breusch-Pagan test
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
 
# Get the test result
test_result = sms.het_breuschpagan(res.resid, res.model.exog)
 
lzip(names, test_result)
# Out:
# [('Lagrange multiplier statistic', 27.946214296697512),
#  ('p-value', 8.541943026675444e-07),
#  ('f-value', 14.084649588644627),
#  ('f p-value', 8.133977547953572e-07)]

# %%
#perform White's test
white_test = het_white(res.resid,  res.model.exog)

#define labels to use for output of White's test
labels = ['Test Statistic', 'Test Statistic p-value', 'F-Statistic', 'F-Test p-value']

#print results of White's test
lzip(labels, white_test)
# Out:
# [('Test Statistic', 57.08327550278484),
#  ('Test Statistic p-value', 4.8609869409170625e-11),
#  ('F-Statistic', 11.605032305023498),
#  ('F-Test p-value', 3.943188473017401e-11)]
