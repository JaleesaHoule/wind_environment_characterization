# %%
#insert code from lab ---- one notebook for creating the heatmaps; one for the regression stuff

# %%
# regression plots

# %%
mpl.rcParams.update({'font.size': 22})

c=['steelblue', 'seagreen', 'purple', 'seagreen', 'purple', 'purple', 'steelblue', 'steelblue', 'purple', 'purple', 'purple', 'steelblue', 'steelblue', 'seagreen', 'seagreen', 'seagreen']

fig, ax =plt.subplots(nrows=1, ncols=3, figsize=(24,7))

#ax[0].scatter(alltemp[0].time*.1, np.abs(alltemp[0].direction_std), s=20, color=c[0], alpha=.6, label='desert/valley')
ax[1].scatter(alltemp[0].speed_avg, np.abs(alltemp[0].direction_std),  s=20, color=c[0], alpha=.6, label='desert/valley')
#ax[0].scatter(alltemp[1].time*.1, np.abs(alltemp[1].direction_std), s=20, color=c[1], alpha=.6, label='forest')
ax[1].scatter(alltemp[1].speed_avg, np.abs(alltemp[1].direction_std),  s=20, color=c[1], alpha=.6, label='forest')
#ax[0].scatter(alltemp[2].time*.1, np.abs(alltemp[2].direction_std), s=20, color=c[2], alpha=.6, label='urban')
ax[1].scatter(alltemp[2].speed_avg, np.abs(alltemp[2].direction_std),  s=20, color=c[2], alpha=.6, label='urban')

# add mean lines
#ax[0].plot(desertchunks.distance, abline_values_desertdist2, 'blue', linewidth=5)
#ax[0].plot(forestchunks.distance, abline_values_forestdist2, 'darkgreen',linewidth=5)
#ax[0].plot(urbanchunks.distance, abline_values_urbandist2, 'indigo', linewidth=5)

#ax[1].plot(deserttemp.speed_avg, abline_values_desertdirection3, 'blue', linewidth=5)
#ax[1].plot(foresttemp.speed_avg, abline_values_forestdirection3, 'darkgreen',linewidth=5)
#ax[1].plot(urbantemp.speed_avg, abline_values_urbandirection3, 'indigo', linewidth=5)


for i in range(3,16):
    #ax[0].scatter(alltemp[i].time*.1,  np.abs(alltemp[i].direction_std), s=20, color=c[i], alpha=.6)
    ax[1].scatter(alltemp[i].speed_avg, np.abs(alltemp[i].direction_std),  s=20, color=c[i], alpha=.6)
    #ax[2].scatter(allchunks[i].environment, allchunks[i].direction,  s=20, color=c[i], alpha=.6)

sns.boxplot(x='time', y='direction_std', hue='environment', data=boxplottemporaldf, showfliers=False, palette=['steelblue', 'seagreen', 'purple',], width=.7, ax=ax[0])    

sns.boxplot(x=alltemporaldf.environment, y=alltemporaldf.direction_std, showfliers=False, palette=['steelblue','steelblue', 'seagreen', 'purple',], width=.4, ax=ax[2])
ax[0].set_xticklabels([1,10,100,'','','','','','','',1000])
ax[2].set_xticklabels([.001,.04, .4, 1])
ax[0].set_ylim(0,180)
#ax[1].set_ylim(0,180) 
#ax[2].set_ylim(0,180) 
ax[1].set_xlim(0,7) 
#ax[0].set_xlim(0,100)
ax[0].set_ylabel('Std dev in direction')
ax[0].set_xlabel('Time lag, seconds')  
#ax[1].set_ylabel('Change in direction, degrees')
ax[1].set_xlabel('Avg wind speed, m/s')
ax[2].set_ylabel('')
ax[2].set_xlabel('Estimated surface roughness, meters')
ax[0].grid(False)
ax[1].grid(False)
ax[2].grid(False)


# Set log scale and spines

ax[0].set_facecolor('white')
ax[1].set_facecolor('white')
ax[2].set_facecolor('white')

ax[0].legend(bbox_to_anchor=(1.6,1))
ax[1].legend(bbox_to_anchor=(.6,1))
#ax[2].legend(bbox_to_anchor=(1,1))



fifi.mpl_functions.adjust_spines(ax[0], ['left', 'bottom'],
                                
                                 #xticks=[1,100,500,1000],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)
fifi.mpl_functions.adjust_spines(ax[1], [ 'bottom'],
                                 #xticks=[0,90, 180, 270, 360],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)


# set yticklabels
evenyticks = np.arange(0, 180+20, 20)
yticklabels = [['$' + str(y) + '^{\circ}$', ''] for y in evenyticks]
yticklabels = np.ravel(yticklabels)[0:-1]
#ax[0].set_yticklabels(yticklabels)

fifi.mpl_functions.adjust_spines(ax[2], [ 'bottom'],
                                 
                                 tick_length=2.5,
                                 spine_locations={ 'bottom': 10},
                                 linewidth=0.5)


#ax[0].spines['left'].set_color('black')
#ax[0].spines['bottom'].set_color('black')
##ax[1].spines['left'].set_color('black')
#ax[1].spines['bottom'].set_color('black')
#ax[2].spines['left'].set_color('black')
#ax[2].spines['bottom'].set_color('black')

# %%
mpl.rcParams.update({'font.size': 22})

c=['steelblue', 'seagreen', 'purple', 'seagreen', 'purple', 'purple', 'steelblue', 'steelblue', 'purple', 'purple', 'purple', 'steelblue', 'steelblue', 'seagreen', 'seagreen', 'seagreen']

fig, ax =plt.subplots(nrows=1, ncols=3, figsize=(24,7))

#ax[0].scatter(alltemp[0].time*.1, np.abs(alltemp[0].direction_std), s=20, color=c[0], alpha=.6, label='desert/valley')
ax[1].scatter(alltemp[0].direction_avg, np.abs(alltemp[0].speed_std),  s=20, color=c[0], alpha=.6, label='desert/valley')
#ax[0].scatter(alltemp[1].time*.1, np.abs(alltemp[1].direction_std), s=20, color=c[1], alpha=.6, label='forest')
ax[1].scatter(alltemp[1].direction_avg, np.abs(alltemp[1].speed_std),  s=20, color=c[1], alpha=.6, label='forest')
#ax[0].scatter(alltemp[2].time*.1, np.abs(alltemp[2].direction_std), s=20, color=c[2], alpha=.6, label='urban')
ax[1].scatter(alltemp[2].direction_avg, np.abs(alltemp[2].speed_std),  s=20, color=c[2], alpha=.6, label='urban')

# add mean lines
#ax[0].plot(desertchunks.distance, abline_values_desertdist2, 'blue', linewidth=5)
#ax[0].plot(forestchunks.distance, abline_values_forestdist2, 'darkgreen',linewidth=5)
#ax[0].plot(urbanchunks.distance, abline_values_urbandist2, 'indigo', linewidth=5)

#ax[1].plot(deserttemp.speed_avg, abline_values_desertdirection3, 'blue', linewidth=5)
#ax[1].plot(foresttemp.speed_avg, abline_values_forestdirection3, 'darkgreen',linewidth=5)
#ax[1].plot(urbantemp.speed_avg, abline_values_urbandirection3, 'indigo', linewidth=5)


for i in range(3,16):
    #ax[0].scatter(alltemp[i].time*.1,  np.abs(alltemp[i].direction_std), s=20, color=c[i], alpha=.6)
    ax[1].scatter(alltemp[i].direction_avg, np.abs(alltemp[i].speed_std),  s=20, color=c[i], alpha=.6)
    #ax[2].scatter(allchunks[i].environment, allchunks[i].direction,  s=20, color=c[i], alpha=.6)

sns.boxplot(x='time', y='speed_std', hue='environment', data=boxplottemporaldf, showfliers=False, palette=['steelblue', 'seagreen', 'purple',], width=.7, ax=ax[0])    

sns.boxplot(x=alltemporaldf.environment, y=alltemporaldf.speed_std, showfliers=False, palette=['steelblue','steelblue', 'seagreen', 'purple',], width=.4, ax=ax[2])
ax[0].set_xticklabels([1,10,100,'','','','','','','',1000])
ax[2].set_xticklabels([.001,.04, .4, 1])
ax[0].set_ylim(0,2)
#ax[1].set_ylim(0,180) 
#ax[2].set_ylim(0,180) 
#ax[1].set_xlim(0,7) 
ax[1].set_xlim(0,360)
ax[0].set_ylabel('Std dev in speed, m/s')
ax[0].set_xlabel('Time lag, seconds')  
#ax[1].set_ylabel('Change in direction, degrees')
ax[1].set_xlabel('Avg wind direction, degrees')
ax[2].set_ylabel('')
ax[2].set_xlabel('Estimated surface roughness, meters')
ax[0].grid(False)
ax[1].grid(False)
ax[2].grid(False)


# Set log scale and spines

ax[0].set_facecolor('white')
ax[1].set_facecolor('white')
ax[2].set_facecolor('white')

ax[0].legend(bbox_to_anchor=(1.6,1))
ax[1].legend(bbox_to_anchor=(.6,.9))
#ax[2].legend(bbox_to_anchor=(1,1))



fifi.mpl_functions.adjust_spines(ax[0], ['left', 'bottom'],
                                
                                 #xticks=[1,100,500,1000],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)
fifi.mpl_functions.adjust_spines(ax[1], [ 'bottom'],
                                 xticks=[0,90, 180, 270, 360],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)


# set yticklabels
evenyticks = np.arange(0, 180+20, 20)
yticklabels = [['$' + str(y) + '^{\circ}$', ''] for y in evenyticks]
yticklabels = np.ravel(yticklabels)[0:-1]
#ax[0].set_yticklabels(yticklabels)

fifi.mpl_functions.adjust_spines(ax[2], [ 'bottom'],
                                 
                                 tick_length=2.5,
                                 spine_locations={ 'bottom': 10},
                                 linewidth=0.5)


#ax[0].spines['left'].set_color('black')
#ax[0].spines['bottom'].set_color('black')
##ax[1].spines['left'].set_color('black')
#ax[1].spines['bottom'].set_color('black')
#ax[2].spines['left'].set_color('black')
#ax[2].spines['bottom'].set_color('bl

# %%
# heatmaps

# %%
import matplotlib.image as mpimg
import PIL
from PIL import Image

# %%
im1 = Image.open("10.20.20.jpg")
im2 = Image.open("7.7.21.jpg")
im3 = Image.open("9.26.21.jpg")
im4 = Image.open("10.29.21.jpg")
im5 = Image.open("10.30.21.jpg")
im6 = Image.open("1.8.22.jpg")
im7 = Image.open("1.11.22.jpg")
im8 = Image.open("1.15.22.jpg")
im9 = Image.open("4.30.22.jpg")
im10 = Image.open("5.1.22.jpg")
im11 = Image.open("5.2.22.jpg")
im12 = Image.open("6.1.22.jpg")
im13 = Image.open("6.3.22.jpg")
im14 = Image.open("6.7.22.jpg")
im15 = Image.open("6.8.22.jpg")
im16 = Image.open("6.22.22.jpg")

# %%
fig, ax =plt.subplots(nrows=3, ncols=2, figsize=(22,19), layout='tight')


#ax[0,1].imshow(im_d1, extent=[0,1000,0,180], aspect='auto')

ax[0,0].scatter(time, df14.D_2.iloc[20000:40000], s=8, color='k', label='forest 6.7.22')
ax[1,0].scatter(time, df8.D_1.iloc[8000:28000], s=8, color='k',label='lemmon valley, 1.15.22')
ax[2,0].scatter(time, df6.D_3.loc[80001:100000], s=8, color='k',label='backyard, 1.8.22')



#sns.heatmap(freq_df1d.T,  robust=True, ax=ax[0,1])
#ax[0,1].imshow(freq_df1d.T, cmap='rocket', vmin=0, vmax=1900, origin='lower', interpolation = 'bilinear',extent=[0,1000,0,180], aspect='auto')
#ax[1,1].imshow(freq_df2d.T, cmap='rocket', vmin=0, vmax=800, origin='lower', interpolation = 'bilinear',extent=[0,1000,0,180], aspect='auto')
#ax[2,1].imshow(freq_df3d.T, cmap='rocket', vmin=0, vmax=800, origin='lower', interpolation = 'bilinear',extent=[0,1000,0,180], aspect='auto')

ax[0,1].pcolormesh(freq_df1d.index.astype('float'), freq_df1d.columns, F_1, cmap='rocket', vmin=0, vmax=2800, shading='gouraud', rasterized=True) 
ax[0,1].set_xscale('log')
ax[1,1].pcolormesh(freq_df2d.index.astype('float'), freq_df2d.columns, F_2, cmap='rocket', vmin=0, vmax=1000, shading='gouraud', rasterized=True) 
ax[1,1].set_xscale('log')

ax[2,1].pcolormesh(freq_df3d.index.astype('float'), freq_df3d.columns, F_3, cmap='rocket', vmin=0, vmax=700, shading='gouraud', rasterized=True) 
ax[2,1].set_xscale('log')



ax[0,1].set_xlim(0.1, 1000)
ax[1,1].set_xlim(0.1, 1000)
ax[2,1].set_xlim(0.1, 1000)

#ax[1,1].xaxis.set_major_formatter(ticker.FuncFormatter(myLogFormat))
#ax[1,1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))
# fix the minor ticks and spine
ax[0,1].tick_params(which='minor', length=2.5*0.5, color='black', direction='in', width=0.5)


ax[0,1].spines.bottom.set_bounds((0.1, 1000))
fifi.mpl_functions.adjust_spines(ax[0,1], ['left', 'bottom'],
                                 yticks=np.arange(0, 180+10, 45),
                                 xticks=[.1,1,10, 100,  1000],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)
# fix the minor ticks and spine
ax[1,1].tick_params(which='minor', length=2.5*0.5, color='black', direction='in', width=0.5)
ax[1,1].spines.bottom.set_bounds((0.1, 1000))

fifi.mpl_functions.adjust_spines(ax[1,1], ['left', 'bottom'],
                                 yticks=np.arange(0, 180+10, 45),
                                 xticks=[.1,1,10, 100,  1000],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)


# fix the minor ticks and spine
ax[2,1].tick_params(which='minor', length=2.5*0.5, color='black', direction='in', width=0.5)
ax[2,1].spines.bottom.set_bounds((0.1, 1000))

fifi.mpl_functions.adjust_spines(ax[2,1], ['left', 'bottom'],
                                 yticks=np.arange(0, 180+10, 45),
                                 xticks=[.1,1,10, 100,  1000],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)




fifi.mpl_functions.adjust_spines(ax[0,0], ['left', 'bottom'],
                                
                                 xticks=[0,500,1000,1500,2000],
                                 yticks=np.arange(0, 360+10, 90),
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)


fifi.mpl_functions.adjust_spines(ax[1,0], ['left', 'bottom'],
                                
                                 xticks=[0,500,1000,1500,2000],
                                 yticks=np.arange(0, 360+10, 90),
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)


fifi.mpl_functions.adjust_spines(ax[2,0], ['left', 'bottom'],
                                
                                 xticks=[0,500,1000,1500,2000],
                                 yticks=np.arange(0, 360+10, 90),
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=0.5)



ax[0,0].set_ylabel('Direction, degrees')
ax[1,0].set_ylabel('Direction, degrees')
ax[2,0].set_ylabel('Direction, degrees')

ax[0,1].set_ylabel('Standard deviation \n in direction, degrees')
ax[1,1].set_ylabel('Standard deviation \n in direction, degrees')
ax[2,1].set_ylabel('Standard deviation \n in direction, degrees')



ax[2,0].set_xlabel('Time, sec')
ax[2,1].set_xlabel('Time lag, sec')

# %%
fig, ax = plt.subplots(figsize=(18, 21))
ax.plot(x_axis, y_axis, color='white')
ax.set_xticks(ticks=(.4,1.4,2.5), labels=('desert/valley', 'forest', 'urban' ))
ax.set_ylabel('Average wind speed, m/s')
# Move left and bottom spines outward by 10 points
ax.spines.left.set_position(('outward', 60))
ax.spines.bottom.set_position(('outward', 10))
# Hide the right and top spines
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax7=fig.add_axes([0.1, 0.15, 0.3, 0.2], frameon=False)  #[lowerCorner_x, lowerCorner_y, width, height]
ax7=plt.imshow(im7)
ax8=fig.add_axes([0.1, 0.23, 0.3, 0.2], frameon=False)      #[lowerCorner_x, lowerCorner_y, width, height]
ax8=plt.imshow(im8)
ax12=fig.add_axes([0.1, 0.34, 0.3, 0.2], frameon=False) 
ax12=plt.imshow(im12)
ax1=fig.add_axes([0.1, 0.6, 0.3, 0.2], frameon=False)
ax1=plt.imshow(im1)
ax13=fig.add_axes([0.1, 0.73, 0.3, 0.2], frameon=False) 
ax13=plt.imshow(im13)


ax4=fig.add_axes([0.35, 0.12, 0.3, 0.2], frameon=False)  #[lowerCorner_x, lowerCorner_y, width, height]
ax4=plt.imshow(im4)
ax16=fig.add_axes([0.35, 0.23, 0.3, 0.2], frameon=False)      #[lowerCorner_x, lowerCorner_y, width, height]
ax16=plt.imshow(im16)
ax2=fig.add_axes([0.35, 0.31, 0.3, 0.2], frameon=False)
ax2=plt.imshow(im2)
ax15=fig.add_axes([0.35, 0.36, 0.3, 0.2], frameon=False) 
ax15=plt.imshow(im15)
ax14=fig.add_axes([0.35, 0.4, 0.3, 0.2], frameon=False) 
ax14=plt.imshow(im14)



ax6=fig.add_axes([0.6, 0.12, 0.3, 0.2], frameon=False)  #[lowerCorner_x, lowerCorner_y, width, height]
ax6=plt.imshow(im6)
ax5=fig.add_axes([0.6, 0.25, 0.3, 0.2], frameon=False)      #[lowerCorner_x, lowerCorner_y, width, height]
ax5=plt.imshow(im5)
ax10=fig.add_axes([0.6, 0.31, 0.3, 0.2], frameon=False) 
ax10=plt.imshow(im10)
ax3=fig.add_axes([0.6, 0.36, 0.3, 0.2], frameon=False) 
ax3=plt.imshow(im3)
ax9=fig.add_axes([0.6, 0.42, 0.3, 0.2], frameon=False)
ax9=plt.imshow(im9)
ax11=fig.add_axes([0.6, 0.42, 0.3, 0.2], frameon=False)
ax11=plt.imshow(im11)












ax1.axes.get_xaxis().set_visible(False)
ax1.axes.get_yaxis().set_visible(False)
ax2.axes.get_xaxis().set_visible(False)
ax2.axes.get_yaxis().set_visible(False)
ax3.axes.get_xaxis().set_visible(False)
ax3.axes.get_yaxis().set_visible(False)
ax4.axes.get_xaxis().set_visible(False)
ax4.axes.get_yaxis().set_visible(False)
ax5.axes.get_xaxis().set_visible(False)
ax5.axes.get_yaxis().set_visible(False)
ax6.axes.get_xaxis().set_visible(False)
ax6.axes.get_yaxis().set_visible(False)
ax7.axes.get_xaxis().set_visible(False)
ax7.axes.get_yaxis().set_visible(False)
ax8.axes.get_xaxis().set_visible(False)
ax8.axes.get_yaxis().set_visible(False)
ax9.axes.get_xaxis().set_visible(False)
ax9.axes.get_yaxis().set_visible(False)
ax10.axes.get_xaxis().set_visible(False)
ax10.axes.get_yaxis().set_visible(False)
ax11.axes.get_xaxis().set_visible(False)
ax11.axes.get_yaxis().set_visible(False)
ax12.axes.get_xaxis().set_visible(False)
ax12.axes.get_yaxis().set_visible(False)
ax13.axes.get_xaxis().set_visible(False)
ax13.axes.get_yaxis().set_visible(False)
ax14.axes.get_xaxis().set_visible(False)
ax14.axes.get_yaxis().set_visible(False)
ax15.axes.get_xaxis().set_visible(False)
ax15.axes.get_yaxis().set_visible(False)
ax16.axes.get_xaxis().set_visible(False)
ax16.axes.get_yaxis().set_visible(False)

#plt.xticks(ticks=(.4,1.2,2.5), labels=('desert/valley', 'forest', 'urban' ))
plt.show()
