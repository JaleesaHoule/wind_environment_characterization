# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

import figurefirst as fifi
import time

# %% [markdown]
# # Read in hdf datasets

# %%
df1=pd.read_hdf('10.20.20_maskedgpsdata.hdf')
df2=pd.read_hdf('7.7.21_maskedgpsdata.hdf')
df3=pd.read_hdf('9.26.21_maskedgpsdata.hdf')
df4=pd.read_hdf('10.29.21_maskedgpsdata.hdf')
df5=pd.read_hdf('10.30.21_maskedgpsdata.hdf')
df6=pd.read_hdf('1.8.22_maskedgpsdata.hdf')
df7=pd.read_hdf('1.11.22_maskedgpsdata.hdf')
df8=pd.read_hdf('1.15.22_maskedgpsdata.hdf')
df9=pd.read_hdf('4.30.22_maskedgpsdata.hdf')
df10=pd.read_hdf('5.1.22_maskedgpsdata.hdf')
df11=pd.read_hdf('5.2.22_maskedgpsdata.hdf')
df12=pd.read_hdf('6.1.22_maskedgpsdata.hdf')
df13=pd.read_hdf('6.3.22_maskedgpsdata.hdf')
df14=pd.read_hdf('6.7.22_maskedgpsdata.hdf')
df15=pd.read_hdf('6.8.22_maskedgpsdata.hdf')
df16=pd.read_hdf('6.22.22_maskedgpsdata.hdf')
#df17=pd.read_hdf('indoor_10.21.22.hdf')
#df18=pd.read_hdf('indoor_11.1.22.hdf')

# %%
df=df1
time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(df.time.iloc[0]))
# Out:
# '2020-10-20 10:32:05'

# %%
'''
solar noons
'''

time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(df.time.iloc[0]))
# Out:
# '2020-10-20 10:32:05'

# %%
print(df.keys())
# Out:
# Index(['millis_2', 'lat_2', 'lon_2', 'gps_time_2', 'gps_date_2', 'wind_2',
#        'gps_date_str_2', 'year_2', 'month_2', 'day_2',
#        ...
#        'U_9', 'V_9', 'W_9', 'T_9', 'H_9', 'AD_9', 'MD_9', 'X_9', 'Y_9', 'Z_9'],
#       dtype='object', length=183)

# %%
#get a sense of where sensors were located
#vertically oriented sensors were paired on a tripod with another sensor
#using this to determine which sensor to use for horizontal speed comparison
df=df8
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df.X_1.iloc[0],df.Y_1.iloc[0], s=100, alpha=.9, label='Sensor A')
ax.scatter(df.X_2.iloc[0],df.Y_2.iloc[0], s=100, alpha=.9, label='Sensor B')
ax.scatter(df.X_3.iloc[0],df.Y_3.iloc[0], s=100, alpha=.9, label='Sensor C')
ax.scatter(df.X_4.iloc[0],df.Y_4.iloc[0], s=100, alpha=.9, label='Sensor D')
ax.scatter(df.X_5.iloc[0],df.Y_5.iloc[0], s=100, alpha=.9, label='Sensor E')
ax.scatter(df.X_6.iloc[0],df.Y_6.iloc[0], s=100, alpha=.9, label='Sensor F')
ax.scatter(df.X_7.iloc[0],df.Y_7.iloc[0], s=100, alpha=.9, label='Sensor G')
ax.scatter(df.X_8_verticallyorientated.iloc[0],df.Y_8_verticallyorientated.iloc[0], s=100, alpha=.4, label='Sensor H')
ax.scatter(df.X_9_verticallyorientated.iloc[0],df.Y_9_verticallyorientated.iloc[0], s=100, alpha=.4, label='Sensor I')
ax.legend()

# %% [markdown]
# ## Separating by environment to make plotting easier

# %%
alldfs=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16, ]# df17, df18]
dates=['10/20/20', '7/7/21', '9/26/21', '10/29/21', '10/30/21', '1/8/22', '1/11/22', '1/15/22', '4/30/22', '5/1/22', '5/2/22', '6/1/22', '6/3/22', '6/7/22', '6/8/22','6/22/22']
desert=0,6,7,11,12
forest=1,3,13,14,15
urban=2,4,5,8,9,10
nowind=16,17

# %%
desert_dates=['10/20/20', '1/11/22', '1/15/22', '6/1/22', '6/3/22']
forest_dates=['7/7/21', '10/29/21', '6/7/22', '6/8/22', '6/22/22']
urban_dates=['9/26/21', '10/30/21', '1/8/22', '4/30/22', '5/1/22', '5/2/22']
no_wind_dates=['10/21/22', '11/2/22']

# %%
placeholder=np.zeros(len(df1)) # for df with no vertical vel (desert 10/20/20)

# %%
desert_s2=([df1.S2_2, df7.S2_1,df8.S2_1,df12.S2_8,df13.S2_8])
desert_d=([df1.D_2, df7.D_1,df8.D_1,df12.D_8,df13.D_8])
desert_vert=([placeholder, df7.V_9_verticallyorientated, df8.V_9_verticallyorientated,df12.V_9_verticallyorientated,df13.V_9_verticallyorientated])

forest_s2=([df2.S2_5,df4.S2_1,df14.S2_8,df15.S2_8,df16.S2_8])
forest_d=([df2.D_5,df4.D_7,df14.D_8,df15.D_8,df16.D_8])
forest_vert=([df2.V_7_verticallyorientated,df4.V_9_verticallyorientated,df14.V_9_verticallyorientated,df15.V_9_verticallyorientated,df16.V_9_verticallyorientated])

urban_s2=([df3.S2_6,df5.S2_1,df6.S2_7,df9.S2_8,df10.S2_8,df11.S2_8])
urban_d=([df3.D_6,df5.D_1,df6.D_7,df9.D_8,df10.D_8,df11.D_8])
urban_vert=([df3.V_8_verticallyorientated,df5.V_9_verticallyorientated,df6.V_8_verticallyorientated,df9.V_9_verticallyorientated,df10.V_9_verticallyorientated,df11.V_9_verticallyorientated])
'''
nowind_s2=([df17.S2, df18.S2])
nowind_d=([df17.D, df18.D])
nowind_vert=([df17.W, df18.W])
'''
# Out:
# '\nnowind_s2=([df17.S2, df18.S2])\nnowind_d=([df17.D, df18.D])\nnowind_vert=([df17.W, df18.W])\n'

# %% [markdown]
# # Plots for S2, D and vertical velocity

# %% [markdown]
# ### Desert/Valley

# %%
mpl.rcParams.update({'font.size': 9})

# %%
fig, ax = plt.subplots(nrows=len(desert_s2), ncols=3, layout='tight', figsize=(12,8))
fig.subplots_adjust(left=0.05,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.7)
for i in range(0,len(desert_s2)):
    time=np.linspace(0,len(desert_s2[i])/36000,len(desert_s2[i])) #convert df time to seconds 
    ax[i,0].scatter(time, desert_s2[i],marker='.', s=1,linewidth=None, alpha=.02, color='k', label=desert_dates[i],rasterized=True)
    ax[i,1].scatter(time, desert_d[i],marker='.', s=1, linewidth=None, alpha=.02, color='k', label=desert_dates[i],rasterized=True)
    ax[i,2].scatter(time, desert_vert[i],marker='.', s=1, linewidth=None, alpha=.02, color='k', label=desert_dates[i],rasterized=True)

    #ax[i,0].set_xlim(0,np.max(time))
    #ax[i,1].set_xlim(0,np.max(time))
    #ax[i,2].set_xlim(0,np.max(time))
    
    ax[i,0].set_ylim(0,12.5)
    ax[i,1].set_ylim(0,360)
    ax[i,2].set_ylim(-5, 5)
    
    ax[i,0].set_ylabel('Horizontal \n wind speed (m/s)')
    ax[i,1].set_ylabel('Horizontal \n wind direction')
    ax[i,2].set_ylabel('Vertical \n velocity (m/s)')
    
    ax[i,0].set_xlabel('Time (h)')
    ax[i,1].set_xlabel('Time (h)')
    ax[i,2].set_xlabel('Time (h)')
    
    
    #ax[i,0].set_title(desert_dates[i])
    #ax[i,1].set_title(desert_dates[i])
    #ax[i,2].set_title(desert_dates[i])

    fifi.mpl_functions.adjust_spines(ax[i,0], ['left', 'bottom'],
                                 yticks=[0,2.5,5,7.5,10,12.5],
                                 xticks=np.arange(0,np.max(time)+1, 1),    
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=1)
    fifi.mpl_functions.adjust_spines(ax[i,1], ['left', 'bottom'],
                                 yticks=np.arange(0,400,90),  
                                 xticks=np.arange(0,np.max(time)+1, 1),    
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=1)
    fifi.mpl_functions.adjust_spines(ax[i,2], ['left', 'bottom'],
                                 xticks=np.arange(0,np.max(time)+1, 1),
                                 yticks=[-5, -2.5, 0, 2.5, 5],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=1)


    evenyticks=np.arange(0, 360+90, 90)
    yticklabels=[['$' + str(y) + '^{\circ}$' + '',] for y in evenyticks]
    yticklabels=np.ravel(yticklabels)
    ax[i,1].set_yticklabels(yticklabels)    
fig.savefig('Desert_signals.svg', dpi=800, format='svg')

# %% [markdown]
# ### Forest

# %%
fig, ax = plt.subplots(nrows=len(forest_s2), ncols=3, layout='tight', figsize=(12,8))

fig.subplots_adjust(left=0.05,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.7)


for i in range(0,len(forest_s2)):
    time=np.linspace(0,len(forest_s2[i])/36000,len(forest_s2[i])) #convert df time to hours
    ax[i,0].scatter(time, forest_s2[i],marker='.', s=1,linewidth=None, alpha=.02, color='k', label=forest_dates[i], rasterized=True)
    ax[i,1].scatter(time, forest_d[i],marker='.', s=1,linewidth=None, alpha=.02, color='k',label=forest_dates[i], rasterized=True)
    ax[i,2].scatter(time, forest_vert[i],marker='.', s=1,linewidth=None, alpha=.02, color='k',label=forest_dates[i], rasterized=True)

    
    ax[i,0].set_ylim(0,12.5)
    ax[i,1].set_ylim(0,360)
    ax[i,2].set_ylim(-5, 5)
    
    #ax[i,0].set_ylabel('Horizontal \n wind speed (m/s)')
    #ax[i,1].set_ylabel('Horizontal \n wind direction')
    #ax[i,2].set_ylabel('Vertical \n velocity (m/s)')
    
    #ax[i,0].set_xlabel('Time (h)')
    #ax[i,1].set_xlabel('Time (h)')
    #ax[i,2].set_xlabel('Time (h)')
    
    
    #ax[i,0].set_title(desert_dates[i])
    #ax[i,1].set_title(desert_dates[i])
    #ax[i,2].set_title(desert_dates[i])
    X=np.max(time)
    fifi.mpl_functions.adjust_spines(ax[i,0], ['left', 'bottom'],
                                 yticks=[0,2.5,5,7.5,10,12.5],
                                 xticks=np.arange(0,X+1, 1),    
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)
    fifi.mpl_functions.adjust_spines(ax[i,1], ['left', 'bottom'],
                                 yticks=np.arange(0,400,90),  
                                 xticks=np.arange(0,X+1, 1),     
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)
    fifi.mpl_functions.adjust_spines(ax[i,2], ['left', 'bottom'],
                                 xticks=np.arange(0,X+1, 1),  
                                 yticks=[-5, -2.5, 0, 2.5, 5,],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)


    evenyticks=np.arange(0, 360+90, 90)
    yticklabels=[['$' + str(y) + '^{\circ}$' + '',] for y in evenyticks]
    yticklabels=np.ravel(yticklabels)
    ax[i,1].set_yticklabels(yticklabels)  
    #print(X)    
    
fig.savefig('Forest_signals.svg', dpi=800, format='svg')

# %% [markdown]
# ### Urban

# %%
fig, ax = plt.subplots(nrows=len(urban_s2), ncols=3, layout='tight', figsize=(20,12))

fig.subplots_adjust(left=0.05,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.7)


for i in range(0,len(urban_s2)):
    time=np.linspace(0,len(urban_s2[i])/36000,len(urban_s2[i])) #convert df time to seconds 
    ax[i,0].scatter(time, urban_s2[i], marker='.', s=1, linewidth=None, alpha=.03, color='k', rasterized=True)
    ax[i,1].scatter(time, urban_d[i], marker='.', s=1, linewidth=None, alpha=.03, color='k', rasterized=True)
    ax[i,2].scatter(time, urban_vert[i], marker='.', s=1, linewidth=None, alpha=.03, color='k', rasterized=True)


    
    ax[i,0].set_ylim(0,12.5)
    ax[i,1].set_ylim(0,360)
    ax[i,2].set_ylim(-5, 5)
    

    X=np.max(time)
    fifi.mpl_functions.adjust_spines(ax[i,0], ['left', 'bottom'],
                                 yticks=[0,2.5,5,7.5,10,12.5],
                                 xticks=np.arange(0,X+1, 1),    
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)
    fifi.mpl_functions.adjust_spines(ax[i,1], ['left', 'bottom'],
                                 yticks=np.arange(0,400,90),  
                                 xticks=np.arange(0,X+1, 1),     
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)
    fifi.mpl_functions.adjust_spines(ax[i,2], ['left', 'bottom'],
                                 xticks=np.arange(0,X+1, 1),  
                                 yticks=[-5, -2.5, 0, 2.5, 5],
                                 tick_length=2.5,
                                 spine_locations={'left': 5, 'bottom': 5},
                                 linewidth=.5)


    evenyticks=np.arange(0, 360+90, 90)
    yticklabels=[['$' + str(y) + '^{\circ}$' + '',] for y in evenyticks]
    yticklabels=np.ravel(yticklabels)
    ax[i,1].set_yticklabels(yticklabels) 
    
    
fig.savefig('Urban_signals.svg', dpi=800, format='svg')

# %% [markdown]
# ### for Figure 2

# %%
#making nicer sensor orientation plot
fig, ax = plt.subplots(figsize=(10,6), layout='tight')
ax.scatter(df.X_1.iloc[0],df.Y_1.iloc[0], s=600, marker="s",edgecolors='none', label='Sensor A', color='silver')
ax.scatter(df.X_2.iloc[0],df.Y_2.iloc[0], s=600, marker="s",edgecolors='none', label='Sensor B', color='silver')
ax.scatter(df.X_3.iloc[0],df.Y_3.iloc[0], s=600, marker="s",edgecolors='none', label='Sensor C', color='silver')
ax.scatter(df.X_4.iloc[0],df.Y_4.iloc[0], s=600, marker="s",edgecolors='none', label='Sensor D', color='royalblue')
ax.scatter(df.X_5.iloc[0],df.Y_5.iloc[0], s=600, marker="s",edgecolors='none', label='Sensor E', color='silver')
ax.scatter(df.X_6.iloc[0],df.Y_6.iloc[0], s=600,marker= "s",edgecolors='none', label='Sensor F', color='indianred')
ax.scatter(df.X_7.iloc[0],df.Y_7.iloc[0], s=600,marker= "s",edgecolors='none', label='Sensor G', color='silver')
#ax.scatter(df.X_8_verticallyorientated,df.Y_8_verticallyorientated, s=200,marker= "d",color='slategray', alpha=.4, label='Sensor H \n(vertically orientated)')
#ax.scatter(df.X_9_verticallyorientated,df.Y_9_verticallyorientated, s=200,marker= "d", color='slategray', alpha=.4, label='Sensor I \n (vertically orientated)')

ax.set_xlabel('X position')
ax.set_ylabel('Y position')
fifi.mpl_functions.adjust_spines(ax, ['left', 'bottom'],
 
                                 tick_length=5,
                                 spine_locations={'left': 5, 'bottom': 20},
                                 linewidth=1)
#ax.legend(bbox_to_anchor=(1,1))
fifi.mpl_functions.set_fontsize(ax, 12)

fig.savefig('allsensors.svg', dpi=1800, transparent=True, format='svg')

# %%
#making nicer sensor orientation plot
time=np.linspace(0,len(df)/10, len(df))/60
fig, ax = plt.subplots(figsize=(10,3), layout='tight', rasterized=True)
ax.scatter(time, df.D_6, s=1, alpha=.87, color='indianred')
ax.scatter(time, df.D_4, s=1, alpha=.3, color='royalblue')

ax.set_ylim(0,360)

fifi.mpl_functions.adjust_spines(ax, ['left', 'bottom'],
                                 xticks=np.arange(0,np.max(time),10),
                                 yticks=np.arange(0, 360+10, 90),
                                 tick_length=5,
                                 spine_locations={'left': 0, 'bottom': 20},
                                 linewidth=1)

ax.set_xlabel('Time (min)')
ax.set_ylabel('Wind Direction')

evenyticks=np.arange(0, 360+10, 90)
yticklabels=[['$' + str(y) + '^{\circ}$' + '',] for y in evenyticks]
yticklabels=np.ravel(yticklabels)
ax.set_yticklabels(yticklabels)
fifi.mpl_functions.set_fontsize(ax, 12)

fig.savefig('twosignals.svg', dpi=600, format='svg')
